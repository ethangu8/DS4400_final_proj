# %%
import pandas as pd
import re
from collections import Counter
import math
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# Issues with Data:
#
# bankruptcy_Test_X.csv: Does not contain a class column so we can check our accuracy
# data.csv: Does not use the same attribute list as our bankruptcy_Train, which is larger so we can't use this either

# %%
# Import our data as csv files from Kaggle, values are already normalized and split into test and training data
test_x = pd.read_csv('bankruptcy_Test_X.csv')
train = pd.read_csv('bankruptcy_Train.csv')

# %%
cols = list(train.columns)
x_cols = cols[:-1]

X = train[x_cols]
y = train['class']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %%
len(y_train)
# Out:
# 8000

# %%
train.describe()
# Out:
#               Attr1         Attr2         Attr3         Attr4         Attr5  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.007954     -0.007140     -0.003544      0.005005     -0.004687
# std        1.396405      1.409440      1.015494      0.908020      1.394750
# min       -9.474787   -140.604555    -25.597146     -0.381641   -138.720013
# 25%       -0.079776     -0.055604     -0.516971     -0.192306      0.006798
# 50%       -0.019204      0.000246      0.003186     -0.117972      0.007302
# 75%        0.081218      0.056957      0.585722      0.022705      0.007753
# max      137.557872      2.004925      3.324327     60.825460     11.556238
#
#               Attr6         Attr7         Attr8         Attr9        Attr10  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.001455     -0.006963      0.009053      0.006763      0.007456
# std        1.286713      1.412509      1.064426      1.171199      1.407349
# min      -26.249562   -141.176615     -0.966015     -1.294340     -2.528495
# 25%       -0.016047     -0.008018     -0.445667     -0.388184     -0.068584
# 50%       -0.016047      0.004280     -0.260150     -0.307842      0.000253
# 75%        0.016026      0.024222      0.098874      0.156638      0.070036
# max      121.354736      0.623095     47.504463     62.936396    140.123299
#
#        ...        Attr56        Attr57        Attr58        Attr59  \
# count  ...  10000.000000  10000.000000  10000.000000  10000.000000
# mean   ...      0.009804      0.005208     -0.009751     -0.002655
# std    ...      0.017370      0.718682      0.026124      0.467139
# min    ...     -1.657288    -42.381245     -0.037484     -3.218490
# 25%    ...      0.009315      0.003199     -0.010766     -0.022740
# 50%    ...      0.009838      0.010013     -0.009924     -0.020438
# 75%    ...      0.010693      0.019900     -0.009416     -0.014401
# max    ...      0.036727     37.405312      2.551674     27.969785
#
#              Attr60        Attr61        Attr62        Attr63        Attr64  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.004548      0.014331     -0.006864      0.020750     -0.003984
# std        1.252571      1.171160      0.277288      1.115182      0.930875
# min       -0.048598     -0.412525     -0.022204     -0.743297     -0.050969
# 25%       -0.043418     -0.221237     -0.016847     -0.371384     -0.041603
# 50%       -0.039928     -0.139653     -0.013821     -0.180311     -0.034319
# 75%       -0.031820     -0.002210     -0.009476      0.133244     -0.020507
# max      117.341069     59.139158     23.970250     62.527240     90.774695
#
#               class
# count  10000.000000
# mean       0.020300
# std        0.141032
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 65 columns]

# %%
#Metrics function we can use to evaluate our models
def confusion_matrix(y_true, y_pred):
    """ Generate a confusion matrix.
    y = actual outcomes (0, 1, 2, ...)
    y_pred = predicted outcomes (0, 1, 2, ...)
    return confusion matrix as a numpy array
    """
    
    # Find unique identifiers
    unique_classes = set(y_true) | set(y_pred)
    n_classes = len(unique_classes)
    
    # Create matrix (all zeros)
    matrix = np.zeros(shape=(n_classes, n_classes), dtype=int)
    
    # Pair up each actual outcome with the corresponding prediction
    actual_prediction = list(zip(y_true, y_pred))
    
    # For each pair, increment the correct position in the matrix
    for i,j in actual_prediction:
        matrix[i,j] += 1
        
    return matrix

def metrics(y, y_pred):
    '''
    Parameters:
    y, y_pred (Pandas Series): series representing actual labels(y) and predicted outcomes(y_pred)
    
    Returns:
    model accuracy, sensitivity, specificity, precision, f1-score
    '''
    # Create a confusion matrix with our two series
    cm = confusion_matrix(y, y_pred)
    TN, FP, FN, TP = cm.ravel()
    
     # Accuracy Calcs
    accuracy = (TN + TP)/(TN + FP + FN + TP) 
    
    # Sensitivity Calcs
    # TP (1,1)/ (TP (1,1) + FN (1,0)) <- wherever y actual = 1
    sensitivity = TP/(TP + FN)
    
    # Specificity Calc
    specificity = TN/(TN + FP)
    
    # Precision Calc
    precision = TP/(TP + FP)
    
    # F1 Score Calc
    f1_score = 2 * ((precision * sensitivity) / (precision + sensitivity))
    
    #print(f'Accuracy: {accuracy} \nSensitivity: {sensitivity}\nSpecificity: {specificity}\nPrecision: {precision}\nf1 score: {f1_score}')
    return {'Accuracy': round(accuracy, 4), 'Sensitivity': round(sensitivity, 4), 
            'Specificity': round(specificity, 4), 'Precision': round(precision, 4), 'f1 score': round(f1_score, 4)}

# %%
# Check the amount of companies that went bankrupt in our data
# 0 = did not bankrupt, 1 = bankrupt
Counter(train['class'].tolist())
# Out:
# Counter({0: 9797, 1: 203})

# %% [markdown]
# ## Naive Bayes (not going to use)
# Despite our project proposal suggesting Naive Bayes as a way to classify our data, we decided against it. Reason being, we wanted to implement as many of our attributes in our data as possible, and in doing so, it would be more difficult to calculate probabilities given the sheer amount of attributes that our data contains. Theoretically, we could split our data into smaller subsets of attributes, but we didn't think that it would provide an accurate enough classification given that our attribute list is over 60 attributes

# %% [markdown]
# ## K-Nearest Neighbors

# %%
# Ethan's knn function from HW 3
# Honestly we should probably just use sklearn
from heapq import nlargest # library to get the keys of the largest values in a dict
def knn(vector_list, speakers, k, function):
    '''
    given a dataframe, k neighbors, and a distance metric function
    compare each word vector against every other word vector
    find the k vectors with the highest distance value (in the case of cossim, for euclidean it would need to be smallest)
    find the speakers of those k vectors
    '''
    guesses = list()
    idx_vector_dict = dict(zip(list(range(0, 1000)), vector_list))
    # Loop through our word vectors
    for idx, vector in idx_vector_dict.items():
        distance_dict = {}
        others_dict = {v: idx_vector_dict[v] for v in idx_vector_dict.keys() - {idx}} # so we don't compare against itself
        for i, j in others_dict.items(): # loop through all other word vectors
            distance = function(vector, j) # can sub in another distance function is desired
            distance_dict[i] = distance

        # get the largest differences, which is the most similar for cosine similarity
        k_largest = nlargest(k, distance_dict, key=distance_dict.get) 
        s_list = [speakers[i] for i in k_largest] # find the speaker for each of the nearest neighbors
        guess = max(set(s_list), key=s_list.count) # find out which speaker is represented more
        guesses.append(guess) # append our guess to the list
    return guesses

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Another approach, inspired by https://www.kaggle.com/code/karthik7395/binary-classification-using-neural-networks/notebook
#
# make sure to run these if not already installed:
# - pip install keras
# - pip install tensorflow --user

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers

# %%
hidden_units=100
learning_rate=0.01
hidden_layer_act='tanh'
output_layer_act='sigmoid'
no_epochs=100

model = Sequential()

# %%
model.add(Dense(64, input_shape=(64,), activation=hidden_layer_act))
model.add(Dense(64, activation=hidden_layer_act))
model.add(Dense(1, activation=output_layer_act))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 64)                4160
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  dense_17 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 8,385
# Trainable params: 8,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd=optimizers.SGD(learning_rate=learning_rate)
model.compile(loss='binary_crossentropy',optimizer=sgd, metrics=['acc'])

# %%
model.fit(X_train, y_train, epochs = no_epochs, batch_size = len(train), verbose=2)
# Out:
# Epoch 1/100
# 1/1 - 0s - loss: 0.2846 - acc: 0.9725 - 221ms/epoch - 221ms/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.2827 - acc: 0.9725 - 15ms/epoch - 15ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.2808 - acc: 0.9726 - 18ms/epoch - 18ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.2790 - acc: 0.9730 - 16ms/epoch - 16ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.2771 - acc: 0.9734 - 18ms/epoch - 18ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.2753 - acc: 0.9735 - 16ms/epoch - 16ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.2735 - acc: 0.9735 - 17ms/epoch - 17ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.2717 - acc: 0.9736 - 18ms/epoch - 18ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.2700 - acc: 0.9737 - 18ms/epoch - 18ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.2683 - acc: 0.9740 - 19ms/epoch - 19ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.2666 - acc: 0.9740 - 20ms/epoch - 20ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.2649 - acc: 0.9740 - 15ms/epoch - 15ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.2632 - acc: 0.9743 - 14ms/epoch - 14ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.2616 - acc: 0.9743 - 20ms/epoch - 20ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.2599 - acc: 0.9743 - 14ms/epoch - 14ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.2583 - acc: 0.9744 - 15ms/epoch - 15ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.2567 - acc: 0.9744 - 15ms/epoch - 15ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.2552 - acc: 0.9744 - 13ms/epoch - 13ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.2536 - acc: 0.9747 - 14ms/epoch - 14ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.2521 - acc: 0.9747 - 13ms/epoch - 13ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.2506 - acc: 0.9747 - 15ms/epoch - 15ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.2491 - acc: 0.9749 - 15ms/epoch - 15ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.2476 - acc: 0.9750 - 14ms/epoch - 14ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.2461 - acc: 0.9750 - 14ms/epoch - 14ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.2447 - acc: 0.9751 - 15ms/epoch - 15ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.2433 - acc: 0.9751 - 15ms/epoch - 15ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.2418 - acc: 0.9751 - 18ms/epoch - 18ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.2404 - acc: 0.9750 - 17ms/epoch - 17ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.2391 - acc: 0.9750 - 16ms/epoch - 16ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.2377 - acc: 0.9751 - 16ms/epoch - 16ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.2364 - acc: 0.9751 - 17ms/epoch - 17ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.2350 - acc: 0.9753 - 14ms/epoch - 14ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.2337 - acc: 0.9753 - 13ms/epoch - 13ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.2324 - acc: 0.9753 - 15ms/epoch - 15ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.2311 - acc: 0.9753 - 16ms/epoch - 16ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.2299 - acc: 0.9753 - 21ms/epoch - 21ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.2286 - acc: 0.9753 - 15ms/epoch - 15ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.2274 - acc: 0.9753 - 16ms/epoch - 16ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.2261 - acc: 0.9753 - 15ms/epoch - 15ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.2249 - acc: 0.9754 - 19ms/epoch - 19ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.2237 - acc: 0.9755 - 25ms/epoch - 25ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.2225 - acc: 0.9756 - 32ms/epoch - 32ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.2214 - acc: 0.9758 - 26ms/epoch - 26ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.2202 - acc: 0.9759 - 19ms/epoch - 19ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.2191 - acc: 0.9759 - 18ms/epoch - 18ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.2179 - acc: 0.9759 - 20ms/epoch - 20ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.2168 - acc: 0.9759 - 19ms/epoch - 19ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.2157 - acc: 0.9759 - 19ms/epoch - 19ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.2146 - acc: 0.9759 - 18ms/epoch - 18ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.2135 - acc: 0.9759 - 17ms/epoch - 17ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.2124 - acc: 0.9759 - 13ms/epoch - 13ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.2114 - acc: 0.9759 - 19ms/epoch - 19ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.2103 - acc: 0.9759 - 15ms/epoch - 15ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.2093 - acc: 0.9759 - 13ms/epoch - 13ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.2083 - acc: 0.9760 - 19ms/epoch - 19ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.2073 - acc: 0.9760 - 12ms/epoch - 12ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.2063 - acc: 0.9760 - 15ms/epoch - 15ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.2053 - acc: 0.9760 - 16ms/epoch - 16ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.2043 - acc: 0.9760 - 16ms/epoch - 16ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.2033 - acc: 0.9761 - 14ms/epoch - 14ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.2024 - acc: 0.9761 - 14ms/epoch - 14ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.2014 - acc: 0.9761 - 16ms/epoch - 16ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.2005 - acc: 0.9761 - 14ms/epoch - 14ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.1996 - acc: 0.9761 - 15ms/epoch - 15ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.1986 - acc: 0.9762 - 15ms/epoch - 15ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.1977 - acc: 0.9762 - 15ms/epoch - 15ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.1968 - acc: 0.9762 - 15ms/epoch - 15ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.1959 - acc: 0.9764 - 15ms/epoch - 15ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.1951 - acc: 0.9764 - 15ms/epoch - 15ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.1942 - acc: 0.9764 - 16ms/epoch - 16ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.1933 - acc: 0.9764 - 15ms/epoch - 15ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.1925 - acc: 0.9764 - 16ms/epoch - 16ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.1917 - acc: 0.9765 - 15ms/epoch - 15ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.1908 - acc: 0.9765 - 16ms/epoch - 16ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.1900 - acc: 0.9766 - 17ms/epoch - 17ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.1892 - acc: 0.9766 - 34ms/epoch - 34ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.1884 - acc: 0.9769 - 15ms/epoch - 15ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.1876 - acc: 0.9769 - 15ms/epoch - 15ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.1868 - acc: 0.9770 - 14ms/epoch - 14ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.1860 - acc: 0.9770 - 16ms/epoch - 16ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.1852 - acc: 0.9770 - 14ms/epoch - 14ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.1845 - acc: 0.9770 - 16ms/epoch - 16ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.1837 - acc: 0.9770 - 15ms/epoch - 15ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.1830 - acc: 0.9770 - 16ms/epoch - 16ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.1822 - acc: 0.9770 - 15ms/epoch - 15ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.1815 - acc: 0.9771 - 18ms/epoch - 18ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.1808 - acc: 0.9771 - 20ms/epoch - 20ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.1801 - acc: 0.9771 - 17ms/epoch - 17ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.1794 - acc: 0.9772 - 19ms/epoch - 19ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.1787 - acc: 0.9772 - 17ms/epoch - 17ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.1780 - acc: 0.9772 - 17ms/epoch - 17ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.1773 - acc: 0.9772 - 16ms/epoch - 16ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.1766 - acc: 0.9772 - 17ms/epoch - 17ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.1759 - acc: 0.9772 - 17ms/epoch - 17ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.1753 - acc: 0.9772 - 13ms/epoch - 13ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.1746 - acc: 0.9772 - 14ms/epoch - 14ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.1739 - acc: 0.9772 - 8ms/epoch - 8ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.1733 - acc: 0.9772 - 10ms/epoch - 10ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.1727 - acc: 0.9772 - 8ms/epoch - 8ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.1720 - acc: 0.9772 - 9ms/epoch - 9ms/step

# %%
predictions = model.predict(X_val)
# Out:
# 63/63 [==============================] - 0s 659us/step

# %%
rounded = [int(round(x[0])) for x in predictions]

# %%
accuracy = sum(1 for x,y in zip(rounded,y_val) if x == y) / len(y_val)

# %%
metrics(y_val, rounded)
# Out:
# <ipython-input-63-6a40839816df>:51: RuntimeWarning: invalid value encountered in double_scalars
#   f1_score = 2 * ((precision * sensitivity) / (precision + sensitivity))
# {'Accuracy': 0.978,
#  'Sensitivity': 0.0,
#  'Specificity': 0.9975,
#  'Precision': 0.0,
#  'f1 score': nan}
